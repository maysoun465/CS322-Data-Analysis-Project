# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('final_data_with_weekend.csv')

# %%
df
# Out:
#            state        date       pm25  temp_max  temp_min  temp_mean  \
# 0     California  2023-09-14  13.625000      26.5      11.1       18.9
# 1     California  2023-09-15  14.016667      28.1      12.4       19.8
# 2     California  2023-09-16  10.370833      26.7      16.0       20.2
# 3     California  2023-09-17   7.220833      24.4      13.9       18.0
# 4     California  2023-09-18   9.162500      26.6      10.4       18.3
# ...          ...         ...        ...       ...       ...        ...
# 4992       Texas  2025-12-21  11.350000       6.1      -2.5        2.7
# 4993       Texas  2025-12-22  13.070833       6.1      -6.3       -1.3
# 4994       Texas  2025-12-23   7.886957      11.1       1.1        5.4
# 4995       Texas  2025-12-24  11.279167      10.4       2.0        6.5
# 4996       Texas  2025-12-25   3.300000       9.7       3.6        6.2
#
#       electricity_mwh  year  month  green_percentage   day_name  day_of_week  \
# 0            816728.0  2023      9         47.052985   Thursday            3
# 1            809940.0  2023      9         47.052985     Friday            4
# 2            750465.0  2023      9         47.052985   Saturday            5
# 3            702396.0  2023      9         47.052985     Sunday            6
# 4            759950.0  2023      9         47.052985     Monday            0
# ...               ...   ...    ...               ...        ...          ...
# 4992        1142550.0  2025     12         45.229938     Sunday            6
# 4993        1193281.0  2025     12         45.229938     Monday            0
# 4994        1213147.0  2025     12         45.229938    Tuesday            1
# 4995        1178925.0  2025     12         45.229938  Wednesday            2
# 4996        1131828.0  2025     12         45.229938   Thursday            3
#
#       is_weekend
# 0              0
# 1              0
# 2              1
# 3              1
# 4              0
# ...          ...
# 4992           1
# 4993           0
# 4994           0
# 4995           0
# 4996           0
#
# [4997 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4997 entries, 0 to 4996
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             4997 non-null   object
#  1   date              4997 non-null   object
#  2   pm25              4997 non-null   float64
#  3   temp_max          4997 non-null   float64
#  4   temp_min          4997 non-null   float64
#  5   temp_mean         4997 non-null   float64
#  6   electricity_mwh   4997 non-null   float64
#  7   year              4997 non-null   int64
#  8   month             4997 non-null   int64
#  9   green_percentage  4997 non-null   float64
#  10  day_name          4997 non-null   object
#  11  day_of_week       4997 non-null   int64
#  12  is_weekend        4997 non-null   int64
# dtypes: float64(6), int64(4), object(3)
# memory usage: 507.6+ KB

# %%
df.describe()
# Out:
#               pm25     temp_max     temp_min    temp_mean  electricity_mwh  \
# count  4997.000000  4997.000000  4997.000000  4997.000000     4.997000e+03
# mean      9.176869    20.653892    11.517831    15.596578     7.031546e+05
# std       8.496225     9.665590     9.869723     9.642100     3.098507e+05
# min      -4.000000   -18.000000   -27.500000   -23.900000     2.714600e+05
# 25%       5.039130    14.000000     4.200000     8.700000     4.688820e+05
# 50%       7.650000    23.200000    12.900000    17.700000     6.258330e+05
# 75%      11.150000    28.500000    20.100000    24.200000     8.252850e+05
# max     168.205556    40.400000    29.000000    34.100000     1.739798e+06
#
#               year        month  green_percentage  day_of_week   is_weekend
# count  4997.000000  4997.000000       4997.000000  4997.000000  4997.000000
# mean   2024.301581     7.022413         64.974963     2.999400     0.285371
# std       0.685331     3.519461         18.391689     1.999249     0.451636
# min    2023.000000     1.000000          6.735499     0.000000     0.000000
# 25%    2024.000000     4.000000         52.335639     1.000000     0.000000
# 50%    2024.000000     7.000000         69.933284     3.000000     0.000000
# 75%    2025.000000    10.000000         77.830814     5.000000     1.000000
# max    2025.000000    12.000000         96.402768     6.000000     1.000000

# %%
sns.pairplot(df);
# Out:
# C:\Users\TOP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.hist(figsize=(15,15));

# %%
df.corr(numeric_only=True)
# Out:
#                       pm25  temp_max  temp_min  temp_mean  electricity_mwh  \
# pm25              1.000000 -0.017310 -0.013513  -0.018303         0.178036
# temp_max         -0.017310  1.000000  0.930765   0.976156         0.001895
# temp_min         -0.013513  0.930765  1.000000   0.984483        -0.032642
# temp_mean        -0.018303  0.976156  0.984483   1.000000        -0.017031
# electricity_mwh   0.178036  0.001895 -0.032642  -0.017031         1.000000
# year             -0.075880  0.025067  0.025317   0.027448         0.073675
# month             0.053907  0.079431  0.099374   0.092505         0.000862
# green_percentage -0.134729  0.363706  0.342095   0.360148        -0.318056
# day_of_week       0.021433 -0.003351  0.001709  -0.001210        -0.043020
# is_weekend        0.020368 -0.006816 -0.000513  -0.004354        -0.051991
#
#                       year     month  green_percentage  day_of_week  \
# pm25             -0.075880  0.053907         -0.134729     0.021433
# temp_max          0.025067  0.079431          0.363706    -0.003351
# temp_min          0.025317  0.099374          0.342095     0.001709
# temp_mean         0.027448  0.092505          0.360148    -0.001210
# electricity_mwh   0.073675  0.000862         -0.318056    -0.043020
# year              1.000000 -0.302878         -0.011864    -0.005565
# month            -0.302878  1.000000          0.135328     0.004098
# green_percentage -0.011864  0.135328          1.000000     0.003447
# day_of_week      -0.005565  0.004098          0.003447     1.000000
# is_weekend       -0.005209  0.006049          0.001752     0.790470
#
#                   is_weekend
# pm25                0.020368
# temp_max           -0.006816
# temp_min           -0.000513
# temp_mean          -0.004354
# electricity_mwh    -0.051991
# year               -0.005209
# month               0.006049
# green_percentage    0.001752
# day_of_week         0.790470
# is_weekend          1.000000

# %%
plt.figure(figsize=(10,6))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True)
plt.show()
